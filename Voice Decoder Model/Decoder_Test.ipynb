# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
from keras.callbacks import LearningRateScheduler
from tqdm import tqdm
from keras.layers import Dense, Flatten,Input, Convolution2D, Dropout, Activation, BatchNormalization, Conv2D, MaxPooling2D,AveragePooling2D, Conv2DTranspose, Reshape, UpSampling2D
from keras.models import Sequential, Model, load_model
from keras.regularizers import l2
import tensorflow as tf

# %cd /content/drive/My Drive/
# Out:
# /content/drive/My Drive

# %%
X = np.load('Picture_feature_4096.npy')
Y = np.load('power_law_comp.npy')
Y_predict = np.load('Decoder_X_4096.npy')

# %%
A = Y_predict[0:10,]
B = Y[0:10,]
C = np.pad(B,((0,0),(0,1),(0,4),(0,0)))

# %%
print(np.shape(Y_predict))
from tensorflow.keras.optimizers import Adam
from keras import losses
adam = Adam(learning_rate=0.001, beta_1=0.5, beta_2=0.9799, amsgrad=False)
# Out:
# (3753, 4096)

# %%
decoder = load_model('Decoder_10ea.h5')

# %%
decoder.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_2 (Dense)              (None, 4096)              16781312
# _________________________________________________________________
# dense_3 (Dense)              (None, 25440)             104227680
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 1, 48, 530)        0
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 1, 48, 530)        2120
# _________________________________________________________________
# up_sampling2d_5 (UpSampling2 (None, 1, 144, 530)       0
# _________________________________________________________________
# conv2d_transpose_10 (Conv2DT (None, 4, 290, 530)       4494930
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 4, 290, 530)       2120
# _________________________________________________________________
# conv2d_transpose_11 (Conv2DT (None, 10, 582, 530)      4494930
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 10, 582, 530)      2120
# _________________________________________________________________
# conv2d_transpose_12 (Conv2DT (None, 13, 585, 530)      4494930
# _________________________________________________________________
# up_sampling2d_6 (UpSampling2 (None, 26, 585, 530)      0
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 26, 585, 530)      2120
# _________________________________________________________________
# conv2d_transpose_13 (Conv2DT (None, 29, 588, 275)      2332275
# _________________________________________________________________
# up_sampling2d_7 (UpSampling2 (None, 58, 588, 275)      0
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 58, 588, 275)      1100
# _________________________________________________________________
# conv2d_transpose_14 (Conv2DT (None, 60, 590, 140)      346640
# _________________________________________________________________
# up_sampling2d_8 (UpSampling2 (None, 120, 590, 140)     0
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 120, 590, 140)     560
# _________________________________________________________________
# conv2d_transpose_15 (Conv2DT (None, 123, 593, 140)     313740
# _________________________________________________________________
# up_sampling2d_9 (UpSampling2 (None, 246, 593, 140)     0
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 246, 593, 140)     560
# _________________________________________________________________
# conv2d_transpose_16 (Conv2DT (None, 249, 596, 140)     313740
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 249, 596, 140)     560
# _________________________________________________________________
# conv2d_transpose_17 (Conv2DT (None, 252, 599, 70)      156870
# _________________________________________________________________
# batch_normalization_18 (Batc (None, 252, 599, 70)      280
# _________________________________________________________________
# conv2d_transpose_18 (Conv2DT (None, 255, 602, 70)      78470
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 255, 602, 70)      280
# _________________________________________________________________
# conv2d_transpose_19 (Conv2DT (None, 258, 605, 2)       2242
# =================================================================
# Total params: 138,049,579
# Trainable params: 138,043,669
# Non-trainable params: 5,910
# _________________________________________________________________

# %%
DT = decoder.predict(A)
print(DT)
# Out:
# [[[[4.55341116e-03 0.00000000e+00]
#    [2.02142000e-02 1.18939448e-02]
#    [4.05205078e-02 0.00000000e+00]
#    ...
#    [1.46885859e-02 0.00000000e+00]
#    [0.00000000e+00 0.00000000e+00]
#    [0.00000000e+00 0.00000000e+00]]
#
#   [[0.00000000e+00 0.00000000e+00]
#    [0.00000000e+00 1.93262007e-02]
#    [0.00000000e+00 2.98777549e-03]
#    ...
#    [2.13407315e-02 0.00000000e+00]
#    [2.56999880e-02 0.00000000e+00]
#    [0.00000000e+00 0.00000000e+00]]
#
#   [[0.00000000e+00 0.00000000e+00]
#    [0.00000000e+00 0.00000000e+00]
#    [8.57714284e-03 0.00000000e+00]
#    ...
#    [2.92165764e-02 0.00000000e+00]
#    [2.83302739e-02 0.00000000e+00]
#    [0.00000000e+00 0.00000000e+00]]
#
#   ...
#
#   [[0.00000000e+00 0.00000000e+00]
#    [0.00000000e+00 1.53957438e-02]
#    [0.00000000e+00 0.00000000e+00]
#    ...
#    [0.00000000e+00 0.00000000e+00]
#    [1.59808956e-02 0.00000000e+00]
#    [5.59500977e-03 0.00000000e+00]]
#
#   [[9.22602322e-03 0.00000000e+00]
#    [0.00000000e+00 6.38137572e-05]
#    [0.00000000e+00 0.00000000e+00]
#    ...
#    [0.00000000e+00 0.00000000e+00]
#    [0.00000000e+00 0.00000000e+00]
#    [0.00000000e+00 0.00000000e+00]]
#
#   [[0.00000000e+00 7.06126215e-03]
#    [0.00000000e+00 2.21473109e-02]
#    [0.00000000e+00 0.00000000e+00]
#    ...
#    [0.00000000e+00 0.00000000e+00]
#    [0.00000000e+00 0.00000000e+00]
#    [0.00000000e+00 0.00000000e+00]]]
#
#
#  [[[4.55372967e-03 0.00000000e+00]
#    [2.02177949e-02 1.18847471e-02]
#    [4.05080914e-02 0.00000000e+00]
#    ...
#    [1.46874515e-02 0.00000000e+00]
#    [0.00000000e+00 0.00000000e+00]
#    [0.00000000e+00 0.00000000e+00]]
#
#   [[0.00000000e+00 0.00000000e+00]
#    [0.00000000e+00 1.